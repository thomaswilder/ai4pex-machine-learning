# %%
import tensorflow as tf
# Out:
# 2026-01-22 20:16:30.765614: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-22 20:16:30.808003: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-22 20:16:58.658091: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
logs = '/home/users/twilder/Python/AI4PEX/machine_learning/logs/fit/'

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs --port 6006
# Out:
#       <iframe id="tensorboard-frame-f7a7d5d4c0e1ca3d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f7a7d5d4c0e1ca3d");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
