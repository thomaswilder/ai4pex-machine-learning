# %% [markdown]
# An issue arose when loading the datasets. Dataset 'vor' had an incorrect pandas time index.
#
# Here we assign the correct one so data can be merged.

# %%
import xarray as xr

# %%
directory = "/gws/nopw/j04/ai4pex/twilder/NEMO_data/DINO/EXP16/features/SO_JET/coarsened_data/"
eke = xr.open_dataset(directory + 'MINT_1d_0061-0072_eke_c_SO_JET.nc')
vor = xr.open_dataset(directory + 'MINT_1d_0061-0072_vor_c_SO_JET.nc')

# %%
vor = vor.assign_coords(t=eke.t)
vor
# Out:
# <xarray.Dataset>
# Dimensions:  (t: 4320, y_c: 54, x_c: 60)
# Coordinates:
#     gphit    (y_c, x_c) float64 ...
#     glamt    (y_c, x_c) float64 ...
#   * t        (t) object 0061-01-02 00:00:00 ... 0073-01-01 00:00:00
# Dimensions without coordinates: y_c, x_c
# Data variables:
#     vor      (t, y_c, x_c) float64 ...
# Attributes:
#     description:  DINO EXP16 regridded to EXP4 -> ocean T grid variables

# %%
vor.to_netcdf(directory + 'MINT_1d_0061-0072_vor_c_SO_JET_mod.nc')
